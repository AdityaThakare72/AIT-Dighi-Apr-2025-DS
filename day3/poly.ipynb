# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-5, 5, 0.5)

# %%
y = 2.3 * x + 10

# %%
plt.plot(x, y);

# %%
y1 = 2.3 * (x ** 10) + 10

# %%
plt.plot(x, y1);
